# %% [markdown]
# # Regularized Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from joblib import dump
from sklearn.discriminant_analysis import StandardScaler
from sklearn.preprocessing import MinMaxScaler


df = pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv',
                           delimiter=',',
                           skipinitialspace=True,
                           engine='python')

df.head(5)
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# 0                 12.749771  ...         3644                 12.9
# 1                 11.564429  ...        14692                 12.0
# 2                 12.865239  ...         2373                 19.7
# 3                 13.897321  ...         1789                 14.1
# 4                 11.901798  ...         4661                 13.5
#
#    diabetes_Lower 95% CI  diabetes_Upper 95% CI  diabetes_number  \
# 0                   11.9                   13.8             5462
# 1                   11.0                   13.1            20520
# 2                   18.6                   20.6             3870
# 3                   13.2                   14.9             2511
# 4                   12.6                   14.5             6017
#
#    CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI  CKD_number  \
# 0             3.1               2.9               3.3        1326
# 1             3.2               3.0               3.5        5479
# 2             4.5               4.2               4.8         887
# 3             3.3               3.1               3.6         595
# 4             3.4               3.2               3.7        1507
#
#    Urban_rural_code
# 0                 3
# 1                 4
# 2                 6
# 3                 2
# 4                 2
#
# [5 rows x 108 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 108 entries, fips to Urban_rural_code
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#                fips       TOT_POP           0-9  0-9 y/o % of total pop  \
# count   3140.000000  3.140000e+03  3.140000e+03             3140.000000
# mean   30401.640764  1.041894e+05  1.274030e+04               11.871051
# std    15150.559265  3.335834e+05  4.180730e+04                2.124081
# min     1001.000000  8.800000e+01  0.000000e+00                0.000000
# 25%    18180.500000  1.096325e+04  1.280500e+03               10.594639
# 50%    29178.000000  2.580050e+04  3.057000e+03               11.802727
# 75%    45081.500000  6.791300e+04  8.097000e+03               12.951840
# max    56045.000000  1.010552e+07  1.208253e+06               25.460677
#
#              19-Oct  10-19 y/o % of total pop         20-29  \
# count  3.140000e+03               3140.000000  3.140000e+03
# mean   1.336798e+04                 12.694609  1.446933e+04
# std    4.228439e+04                  1.815044  4.957773e+04
# min    0.000000e+00                  0.000000  0.000000e+00
# 25%    1.374500e+03                 11.674504  1.263750e+03
# 50%    3.274000e+03                 12.687422  3.108000e+03
# 75%    8.822250e+03                 13.659282  8.976250e+03
# max    1.239139e+06                 23.304372  1.557073e+06
#
#        20-29 y/o % of total pop         30-39  30-39 y/o % of total pop  ...  \
# count               3140.000000  3.140000e+03               3140.000000  ...
# mean                  12.283979  1.391649e+04                 11.751535  ...
# std                    3.126297  4.899095e+04                  1.696599  ...
# min                    0.000000  1.100000e+01                  6.092789  ...
# 25%                   10.496774  1.232750e+03                 10.689322  ...
# 50%                   11.772649  3.000500e+03                 11.580861  ...
# 75%                   13.182260  8.314250e+03                 12.639379  ...
# max                   37.570198  1.501844e+06                 22.225129  ...
#
#          COPD_number  diabetes_prevalence  diabetes_Lower 95% CI  \
# count    3140.000000          3140.000000            3140.000000
# mean     5827.242357            13.073503              12.088089
# std     15720.551934             2.724351               2.622948
# min         7.000000             6.100000               5.500000
# 25%       815.000000            11.200000              10.300000
# 50%      1963.500000            12.800000              11.800000
# 75%      4727.000000            14.800000              13.700000
# max    434075.000000            25.600000              24.200000
#
#        diabetes_Upper 95% CI  diabetes_number  CKD_prevalence  \
# count            3140.000000      3140.000000     3140.000000
# mean               14.053726      9326.577707        3.446242
# std                 2.824828     29754.601185        0.568059
# min                 6.700000        11.000000        1.800000
# 25%                12.100000      1187.750000        3.100000
# 50%                13.800000      2743.000000        3.400000
# 75%                15.900000      6679.250000        3.800000
# max                27.000000    952335.000000        6.200000
#
#        CKD_Lower 95% CI  CKD_Upper 95% CI     CKD_number  Urban_rural_code
# count       3140.000000       3140.000000    3140.000000       3140.000000
# mean           3.207516          3.710478    2466.234076          4.635350
# std            0.527740          0.613069    7730.422067          1.510447
# min            1.700000          1.900000       3.000000          1.000000
# 25%            2.900000          3.300000     314.750000          3.000000
# 50%            3.200000          3.700000     718.000000          5.000000
# 75%            3.500000          4.100000    1776.250000          6.000000
# max            5.800000          6.600000  237766.000000          6.000000
#
# [8 rows x 106 columns]

# %%
if df.isnull().sum().sum() > 0 or df.isna().sum().sum():
    df.dropna(axis=1, how=all, inplace=True).reset_index(drop=True)
    print("[+] There are missing values in the dataset")


if df.duplicated().sum() > 0:
    df.drop_duplicates(inplace=True)
    print("[+] There are duplicated values in the dataset")

df = df.select_dtypes(include=['float64', 'int64'])

df.describe()
# Out:
#                fips       TOT_POP           0-9  0-9 y/o % of total pop  \
# count   3140.000000  3.140000e+03  3.140000e+03             3140.000000
# mean   30401.640764  1.041894e+05  1.274030e+04               11.871051
# std    15150.559265  3.335834e+05  4.180730e+04                2.124081
# min     1001.000000  8.800000e+01  0.000000e+00                0.000000
# 25%    18180.500000  1.096325e+04  1.280500e+03               10.594639
# 50%    29178.000000  2.580050e+04  3.057000e+03               11.802727
# 75%    45081.500000  6.791300e+04  8.097000e+03               12.951840
# max    56045.000000  1.010552e+07  1.208253e+06               25.460677
#
#              19-Oct  10-19 y/o % of total pop         20-29  \
# count  3.140000e+03               3140.000000  3.140000e+03
# mean   1.336798e+04                 12.694609  1.446933e+04
# std    4.228439e+04                  1.815044  4.957773e+04
# min    0.000000e+00                  0.000000  0.000000e+00
# 25%    1.374500e+03                 11.674504  1.263750e+03
# 50%    3.274000e+03                 12.687422  3.108000e+03
# 75%    8.822250e+03                 13.659282  8.976250e+03
# max    1.239139e+06                 23.304372  1.557073e+06
#
#        20-29 y/o % of total pop         30-39  30-39 y/o % of total pop  ...  \
# count               3140.000000  3.140000e+03               3140.000000  ...
# mean                  12.283979  1.391649e+04                 11.751535  ...
# std                    3.126297  4.899095e+04                  1.696599  ...
# min                    0.000000  1.100000e+01                  6.092789  ...
# 25%                   10.496774  1.232750e+03                 10.689322  ...
# 50%                   11.772649  3.000500e+03                 11.580861  ...
# 75%                   13.182260  8.314250e+03                 12.639379  ...
# max                   37.570198  1.501844e+06                 22.225129  ...
#
#          COPD_number  diabetes_prevalence  diabetes_Lower 95% CI  \
# count    3140.000000          3140.000000            3140.000000
# mean     5827.242357            13.073503              12.088089
# std     15720.551934             2.724351               2.622948
# min         7.000000             6.100000               5.500000
# 25%       815.000000            11.200000              10.300000
# 50%      1963.500000            12.800000              11.800000
# 75%      4727.000000            14.800000              13.700000
# max    434075.000000            25.600000              24.200000
#
#        diabetes_Upper 95% CI  diabetes_number  CKD_prevalence  \
# count            3140.000000      3140.000000     3140.000000
# mean               14.053726      9326.577707        3.446242
# std                 2.824828     29754.601185        0.568059
# min                 6.700000        11.000000        1.800000
# 25%                12.100000      1187.750000        3.100000
# 50%                13.800000      2743.000000        3.400000
# 75%                15.900000      6679.250000        3.800000
# max                27.000000    952335.000000        6.200000
#
#        CKD_Lower 95% CI  CKD_Upper 95% CI     CKD_number  Urban_rural_code
# count       3140.000000       3140.000000    3140.000000       3140.000000
# mean           3.207516          3.710478    2466.234076          4.635350
# std            0.527740          0.613069    7730.422067          1.510447
# min            1.700000          1.900000       3.000000          1.000000
# 25%            2.900000          3.300000     314.750000          3.000000
# 50%            3.200000          3.700000     718.000000          5.000000
# 75%            3.500000          4.100000    1776.250000          6.000000
# max            5.800000          6.600000  237766.000000          6.000000
#
# [8 rows x 106 columns]

# %%
def identify_outliers(df):
    outlier_info = {}

    for col in df.select_dtypes(include='number').columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1 

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

        if not outliers.empty:
            outlier_info[col] = {
                'outliers_count': outliers.shape[0],
                'lower_bound': lower_bound,
                'upper_bound': upper_bound,
                'outlier_values': outliers[col].tolist()
            }

    for col, info in outlier_info.items():
        print(f"Column: {col}")
        print(f"  Number of outliers: {info['outliers_count']}")
        print(f"  Low Limit: {info['lower_bound']}")
        print(f"  High Limit: {info['upper_bound']}")
        print(f"  Outliers: {info['outlier_values'][:5]}...\n")
    return outlier_info

# %%
def remove_outliers(df, outlier_info):
    
    for col, info in outlier_info.items():
        lower_limit = info['lower_bound']
        upper_limit = info['upper_bound']
        
        if lower_limit < 0:
            df = df[df[col] >= lower_limit]
        if upper_limit > 0:
            df = df[df[col] <= upper_limit]

        
    return df

# %%
outlier_info = identify_outliers(df)
# Out:
# Column: TOT_POP
#   Number of outliers: 432
#   Low Limit: -74461.375
#   High Limit: 153337.625
#   Outliers: [218022, 659300, 163941, 366519, 413757]...
#
# Column: 0-9
#   Number of outliers: 429
#   Low Limit: -8944.25
#   High Limit: 18321.75
#   Outliers: [24757, 83866, 19180, 43078, 53407]...
#
# Column: 0-9 y/o % of total pop
#   Number of outliers: 114
#   Low Limit: 7.0588377662499955
#   High Limit: 16.487640596250003
#   Outliers: [6.360300542, 21.51954326, 19.6, 25.46067686, 17.2652804]...
#
# Column: 19-Oct
#   Number of outliers: 431
#   Low Limit: -9797.125
#   High Limit: 19993.875
#   Outliers: [26913, 82823, 23398, 46922, 53561]...
#
# Column: 10-19 y/o % of total pop
#   Number of outliers: 137
#   Low Limit: 8.697336139999999
#   High Limit: 16.63644994
#   Outliers: [6.569980779, 17.6438296, 8.665906499, 18.59568831, 16.95643485]...
#
# Column: 20-29
#   Number of outliers: 438
#   Low Limit: -10305.0
#   High Limit: 20545.0
#   Outliers: [23579, 91855, 34582, 50959, 57388]...
#
# Column: 20-29 y/o % of total pop
#   Number of outliers: 204
#   Low Limit: 6.468544207500002
#   High Limit: 17.2104902675
#   Outliers: [21.09417412, 18.63983947, 24.3985842, 20.98337404, 19.82853943]...
#
# Column: 30-39
#   Number of outliers: 431
#   Low Limit: -9389.5
#   High Limit: 18936.5
#   Outliers: [25213, 89590, 20928, 48362, 53044]...
#
# Column: 30-39 y/o % of total pop
#   Number of outliers: 88
#   Low Limit: 7.7642376849999994
#   High Limit: 15.564463085000002
#   Outliers: [16.91420584, 15.59453656, 21.34146341, 16.16976762, 16.54534295]...
#
# Column: 40-49
#   Number of outliers: 433
#   Low Limit: -9067.625
#   High Limit: 18433.375
#   Outliers: [27338, 80221, 19365, 44447, 48602]...
#
# Column: 40-49 y/o % of total pop
#   Number of outliers: 69
#   Low Limit: 8.133868276249999
#   High Limit: 14.937412626250001
#   Outliers: [19.43036869, 16.02719767, 7.997109479, 15.24390244, 7.626315291]...
#
# Column: 50-59
#   Number of outliers: 423
#   Low Limit: -10028.375
#   High Limit: 20668.625
#   Outliers: [29986, 83769, 54475, 53867, 28056]...
#
# Column: 50-59 y/o % of total pop
#   Number of outliers: 107
#   Low Limit: 10.202730187500004
#   High Limit: 16.964945307499995
#   Outliers: [19.22068845, 17.21778791, 17.28994658, 17.20130172, 9.635071661]...
#
# Column: 60-69
#   Number of outliers: 402
#   Low Limit: -9374.5
#   High Limit: 19561.5
#   Outliers: [29932, 78622, 40881, 49214, 25618]...
#
# Column: 60-69 y/o % of total pop
#   Number of outliers: 118
#   Low Limit: 7.352197581250003
#   High Limit: 18.736288271249997
#   Outliers: [19.32093775, 6.190533542, 6.700560553, 18.89732321, 19.55662455]...
#
# Column: 70-79
#   Number of outliers: 373
#   Low Limit: -5984.125
#   High Limit: 12508.875
#   Outliers: [20936, 43004, 24151, 29685, 14341]...
#
# Column: 70-79 y/o % of total pop
#   Number of outliers: 119
#   Low Limit: 3.4120230551250015
#   High Limit: 13.066029404124997
#   Outliers: [2.254062555, 3.238910848, 2.372636396, 3.337330136, 2.603322528]...
#
# Column: 80+
#   Number of outliers: 394
#   Low Limit: -3017.125
#   High Limit: 6449.875
#   Outliers: [9368, 25550, 13244, 14989, 8113]...
#
# Column: 80+ y/o % of total pop
#   Number of outliers: 99
#   Low Limit: 1.120405860375
#   High Limit: 8.102385609375
#   Outliers: [0.61156736, 1.095989401, 1.073743922, 11.2854299, 8.256624826]...
#
# Column: White-alone pop
#   Number of outliers: 407
#   Low Limit: -65956.75
#   High Limit: 133951.25
#   Outliers: [190301, 350457, 252338, 244947, 178681]...
#
# Column: % White-alone
#   Number of outliers: 236
#   Low Limit: 55.76859182750003
#   High Limit: 119.37360850749998
#   Outliers: [49.06957116, 26.24778063, 52.25101626, 53.43227425, 51.63313513]...
#
# Column: Black-alone pop
#   Number of outliers: 436
#   Low Limit: -8292.5
#   High Limit: 14199.5
#   Outliers: [19492, 24153, 26994, 17570, 16094]...
#
# Column: % Black-alone
#   Number of outliers: 394
#   Low Limit: -14.110407521250004
#   High Limit: 25.829528788750004
#   Outliers: [48.39837627, 70.70428092, 44.91361789, 40.0, 41.70235963]...
#
# Column: Native American/American Indian-alone pop
#   Number of outliers: 466
#   Low Limit: -816.5
#   High Limit: 1555.5
#   Outliers: [1684, 1892, 1913, 2968, 3885]...
#
# Column: % NA/AI-alone
#   Number of outliers: 374
#   Low Limit: -1.0363890465
#   High Limit: 2.7520983715
#   Outliers: [3.872319582, 5.80453318, 7.858102332, 11.77704001, 8.871913781]...
#
# Column: Asian-alone pop
#   Number of outliers: 525
#   Low Limit: -1156.875
#   High Limit: 2080.125
#   Outliers: [2508, 11676, 6876, 9815, 8548]...
#
# Column: % Asian-alone
#   Number of outliers: 379
#   Low Limit: -0.9859687082499999
#   High Limit: 2.88503860575
#   Outliers: [4.194191813, 3.190513946, 41.21964005, 10.09062283, 5.342399223]...
#
# Column: Hawaiian/Pacific Islander-alone pop
#   Number of outliers: 469
#   Low Limit: -91.0
#   High Limit: 165.0
#   Outliers: [206, 457, 318, 376, 185]...
#
# Column: % Hawaiian/PI-alone
#   Number of outliers: 295
#   Low Limit: -0.097903041375
#   High Limit: 0.248227469625
#   Outliers: [0.749654764, 0.396848331, 0.640190516, 0.310240876, 0.248700698]...
#
# Column: Two or more races pop
#   Number of outliers: 452
#   Low Limit: -1795.5
#   High Limit: 3472.5
#   Outliers: [3891, 8398, 9703, 6869, 24313]...
#
# Column: % Two or more races
#   Number of outliers: 185
#   Low Limit: -0.2210637984999997
#   High Limit: 3.9885908494999995
#   Outliers: [4.800194192, 4.263498165, 8.339564654, 19.27023945, 4.273919378]...
#
# Column: POP_ESTIMATE_2018
#   Number of outliers: 432
#   Low Limit: -74461.375
#   High Limit: 153337.625
#   Outliers: [218022, 659300, 163941, 366519, 413757]...
#
# Column: N_POP_CHG_2018
#   Number of outliers: 548
#   Low Limit: -645.75
#   High Limit: 868.25
#   Outliers: [5403, -925, 2300, 2098, 4854]...
#
# Column: GQ_ESTIMATES_2018
#   Number of outliers: 362
#   Low Limit: -2930.25
#   High Limit: 5349.75
#   Outliers: [16694, 8320, 7277, 9120, 10557]...
#
# Column: R_birth_2018
#   Number of outliers: 119
#   Low Limit: 5.649999999999998
#   High Limit: 16.450000000000003
#   Outliers: [5.4, 24.0, 20.7, 30.1, 23.8]...
#
# Column: R_death_2018
#   Number of outliers: 38
#   Low Limit: 3.4499999999999993
#   High Limit: 17.45
#   Outliers: [1.9, 0.5, 19.9, 21.9, 0.0]...
#
# Column: R_NATURAL_INC_2018
#   Number of outliers: 85
#   Low Limit: -9.0
#   High Limit: 10.2
#   Outliers: [16.4, 13.1, 12.1, 10.8, 11.2]...
#
# Column: R_INTERNATIONAL_MIG_2018
#   Number of outliers: 274
#   Low Limit: -1.9500000000000002
#   High Limit: 3.25
#   Outliers: [26.2, 3.9, 12.6, 7.5, 3.7]...
#
# Column: R_DOMESTIC_MIG_2018
#   Number of outliers: 138
#   Low Limit: -24.499999999999996
#   High Limit: 24.299999999999997
#   Outliers: [24.3, -30.6, -29.6, -30.2, -30.1]...
#
# Column: R_NET_MIG_2018
#   Number of outliers: 155
#   Low Limit: -22.737499999999997
#   High Limit: 24.562499999999996
#   Outliers: [24.8, -24.1, -25.0, -23.7, 31.0]...
#
# Column: Less than a high school diploma 2014-18
#   Number of outliers: 338
#   Low Limit: -6144.625
#   High Limit: 12888.375
#   Outliers: [14310, 46025, 21617, 38247, 21646]...
#
# Column: High school diploma only 2014-18
#   Number of outliers: 372
#   Low Limit: -15809.75
#   High Limit: 33826.25
#   Outliers: [40579, 120037, 50768, 92986, 38289]...
#
# Column: Some college or associate's degree 2014-18
#   Number of outliers: 419
#   Low Limit: -15880.25
#   High Limit: 32587.75
#   Outliers: [46025, 137208, 69750, 82763, 41976]...
#
# Column: Bachelor's degree or higher 2014-18
#   Number of outliers: 474
#   Low Limit: -12740.75
#   High Limit: 24439.25
#   Outliers: [46075, 145462, 32377, 101650, 63703]...
#
# Column: Percent of adults with less than a high school diploma 2014-18
#   Number of outliers: 58
#   Low Limit: -3.799999999999997
#   High Limit: 29.799999999999997
#   Outliers: [30.6, 31.0, 30.6, 30.2, 34.3]...
#
# Column: Percent of adults with a high school diploma only 2014-18
#   Number of outliers: 32
#   Low Limit: 15.550000000000006
#   High Limit: 53.54999999999999
#   Outliers: [53.6, 10.9, 12.3, 15.0, 14.5]...
#
# Column: Percent of adults completing some college or associate's degree 2014-18
#   Number of outliers: 29
#   Low Limit: 16.949999999999996
#   High Limit: 44.550000000000004
#   Outliers: [45.2, 48.0, 15.9, 16.4, 16.1]...
#
# Column: Percent of adults with a bachelor's degree or higher 2014-18
#   Number of outliers: 144
#   Low Limit: -0.9000000000000021
#   High Limit: 41.5
#   Outliers: [41.7, 42.1, 43.5, 46.0, 41.7]...
#
# Column: POVALL_2018
#   Number of outliers: 367
#   Low Limit: -10103.375
#   High Limit: 21097.625
#   Outliers: [21719, 103604, 30075, 42667, 84539]...
#
# Column: PCTPOVALL_2018
#   Number of outliers: 92
#   Low Limit: -0.4499999999999993
#   High Limit: 29.55
#   Outliers: [30.9, 42.5, 31.4, 30.1, 30.2]...
#
# Column: PCTPOV017_2018
#   Number of outliers: 50
#   Low Limit: -3.200000000000003
#   High Limit: 44.0
#   Outliers: [68.3, 48.0, 52.8, 48.1, 50.6]...
#
# Column: PCTPOV517_2018
#   Number of outliers: 59
#   Low Limit: -3.849999999999996
#   High Limit: 42.14999999999999
#   Outliers: [66.5, 45.3, 42.5, 49.7, 53.2]...
#
# Column: MEDHHINC_2018
#   Number of outliers: 140
#   Low Limit: 20959.125
#   High Limit: 81540.125
#   Outliers: [82633, 82113, 89276, 101744, 101463]...
#
# Column: CI90LBINC_2018
#   Number of outliers: 152
#   Low Limit: 18106.25
#   High Limit: 75818.25
#   Outliers: [76360, 78006, 82607, 100351, 100009]...
#
# Column: CI90UBINC_2018
#   Number of outliers: 138
#   Low Limit: 24272.375
#   High Limit: 86579.375
#   Outliers: [88906, 95945, 103137, 102917, 86684]...
#
# Column: Civilian_labor_force_2018
#   Number of outliers: 445
#   Low Limit: -35153.0
#   High Limit: 71711.0
#   Outliers: [93849, 314014, 74654, 179752, 187406]...
#
# Column: Employed_2018
#   Number of outliers: 445
#   Low Limit: -33729.75
#   High Limit: 68788.25
#   Outliers: [90456, 302359, 71951, 173532, 178608]...
#
# Column: Unemployed_2018
#   Number of outliers: 423
#   Low Limit: -1412.5
#   High Limit: 2889.5
#   Outliers: [3393, 11655, 6220, 8798, 4219]...
#
# Column: Unemployment_rate_2018
#   Number of outliers: 95
#   Low Limit: 0.5500000000000003
#   High Limit: 7.35
#   Outliers: [7.5, 9.6, 12.8, 7.8, 8.2]...
#
# Column: Median_Household_Income_2018
#   Number of outliers: 140
#   Low Limit: 20959.125
#   High Limit: 81540.125
#   Outliers: [82633, 82113, 89276, 101744, 101463]...
#
# Column: Med_HH_Income_Percent_of_State_Total_2018
#   Number of outliers: 103
#   Low Limit: 41.7
#   High Limit: 133.7
#   Outliers: [151.7, 146.5, 135.2, 135.2, 134.8]...
#
# Column: Active Physicians per 100000 Population 2018 (AAMC)
#   Number of outliers: 120
#   Low Limit: 150.79999999999995
#   High Limit: 355.6
#   Outliers: [847.0, 386.0, 386.0, 386.0, 386.0]...
#
# Column: Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)
#   Number of outliers: 144
#   Low Limit: 146.20000000000005
#   High Limit: 297.4
#   Outliers: [302.9, 302.9, 302.9, 302.9, 302.9]...
#
# Column: Active Primary Care Physicians per 100000 Population 2018 (AAMC)
#   Number of outliers: 45
#   Low Limit: 54.64999999999998
#   High Limit: 119.85000000000002
#   Outliers: [239.7, 128.9, 128.9, 128.9, 128.9]...
#
# Column: Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)
#   Number of outliers: 45
#   Low Limit: 51.45000000000001
#   High Limit: 108.65
#   Outliers: [179.4, 119.7, 119.7, 119.7, 119.7]...
#
# Column: Active General Surgeons per 100000 Population 2018 (AAMC)
#   Number of outliers: 162
#   Low Limit: 4.8
#   High Limit: 10.400000000000002
#   Outliers: [25.3, 12.1, 12.1, 12.1, 12.1]...
#
# Column: Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)
#   Number of outliers: 218
#   Low Limit: 4.449999999999999
#   High Limit: 8.850000000000001
#   Outliers: [15.2, 11.7, 11.7, 11.7, 11.7]...
#
# Column: Total nurse practitioners (2019)
#   Number of outliers: 423
#   Low Limit: -39.22553242562499
#   High Limit: 79.88024761137498
#   Outliers: [113.1621137, 342.2029959, 85.09191773, 190.2379795, 214.7563856]...
#
# Column: Total physician assistants (2019)
#   Number of outliers: 418
#   Low Limit: -21.707942859375
#   High Limit: 42.782360291625
#   Outliers: [72.16342248, 45.28760988, 136.7872933, 46.43640008, 50.48974965]...
#
# Column: Total Hospitals (2019)
#   Number of outliers: 389
#   Low Limit: -1.34538510475
#   High Limit: 2.9057676592500004
#   Outliers: [4.505074295, 13.62337508, 3.387577332, 7.573526183, 8.549623548]...
#
# Column: Internal Medicine Primary Care (2019)
#   Number of outliers: 432
#   Low Limit: -43.244171316875004
#   High Limit: 84.99048587812501
#   Outliers: [101.9217303, 308.2120007, 171.3416567, 193.4246516, 105.5405216]...
#
# Column: Family Medicine/General Practice Primary Care (2019)
#   Number of outliers: 416
#   Low Limit: -33.68735572375
#   High Limit: 70.31241441825
#   Outliers: [83.32157211, 251.9649966, 140.0727417, 158.1257108, 86.27995379]...
#
# Column: Total Specialist Physicians (2019)
#   Number of outliers: 426
#   Low Limit: -118.95382448749999
#   High Limit: 237.56324629249997
#   Outliers: [282.882982, 855.4400474, 475.557456, 536.848639, 292.9269095]...
#
# Column: ICU Beds_x
#   Number of outliers: 455
#   Low Limit: -18.0
#   High Limit: 30.0
#   Outliers: [51, 56, 66, 471, 48]...
#
# Column: Total Population
#   Number of outliers: 424
#   Low Limit: -73833.625
#   High Limit: 152301.375
#   Outliers: [203360, 659460, 156597, 353213, 414328]...
#
# Column: Population Aged 60+
#   Number of outliers: 381
#   Low Limit: -17122.5
#   High Limit: 36043.5
#   Outliers: [53519, 138161, 70040, 88103, 44214]...
#
# Column: Percent of Population Aged 60+
#   Number of outliers: 71
#   Low Limit: 11.299999999999997
#   High Limit: 37.7
#   Outliers: [8.3, 11.0, 44.8, 38.5, 38.9]...
#
# Column: CNTY_FIPS
#   Number of outliers: 178
#   Low Limit: -112.0
#   High Limit: 280.0
#   Outliers: [282, 290, 281, 283, 285]...
#
# Column: county_pop2018_18 and older
#   Number of outliers: 431
#   Low Limit: -58079.75
#   High Limit: 119360.25
#   Outliers: [170912, 509229, 129048, 286553, 317046]...
#
# Column: anycondition_prevalence
#   Number of outliers: 48
#   Low Limit: 30.749999999999996
#   High Limit: 63.150000000000006
#   Outliers: [29.6, 30.1, 23.9, 28.2, 28.4]...
#
# Column: anycondition_Lower 95% CI
#   Number of outliers: 45
#   Low Limit: 28.649999999999995
#   High Limit: 61.05
#   Outliers: [27.7, 28.4, 22.6, 26.8, 26.8]...
#
# Column: anycondition_Upper 95% CI
#   Number of outliers: 53
#   Low Limit: 32.849999999999994
#   High Limit: 65.25
#   Outliers: [32.5, 31.5, 31.8, 25.1, 29.5]...
#
# Column: anycondition_number
#   Number of outliers: 390
#   Low Limit: -26964.375
#   High Limit: 56180.625
#   Outliers: [68790, 233701, 127744, 155134, 89485]...
#
# Column: Obesity_prevalence
#   Number of outliers: 80
#   Low Limit: 24.15
#   High Limit: 46.15
#   Outliers: [47.4, 23.4, 23.1, 21.4, 22.1]...
#
# Column: Obesity_Lower 95% CI
#   Number of outliers: 71
#   Low Limit: 22.550000000000004
#   High Limit: 44.54999999999999
#   Outliers: [46.1, 22.2, 20.1, 20.7, 20.7]...
#
# Column: Obesity_Upper 95% CI
#   Number of outliers: 87
#   Low Limit: 25.712500000000002
#   High Limit: 47.8125
#   Outliers: [47.9, 25.5, 48.6, 24.2, 24.0]...
#
# Column: Obesity_number
#   Number of outliers: 402
#   Low Limit: -20126.25
#   High Limit: 41743.75
#   Outliers: [50761, 175684, 94849, 116990, 63314]...
#
# Column: Heart disease_prevalence
#   Number of outliers: 13
#   Low Limit: 3.8
#   High Limit: 13.400000000000002
#   Outliers: [14.5, 13.6, 13.7, 3.5, 13.8]...
#
# Column: Heart disease_Lower 95% CI
#   Number of outliers: 9
#   Low Limit: 3.4
#   High Limit: 12.200000000000001
#   Outliers: [12.9, 3.3, 12.5, 12.6, 12.6]...
#
# Column: Heart disease_Upper 95% CI
#   Number of outliers: 23
#   Low Limit: 4.449999999999999
#   High Limit: 14.45
#   Outliers: [16.1, 14.6, 14.9, 15.0, 15.8]...
#
# Column: Heart disease_number
#   Number of outliers: 373
#   Low Limit: -4567.75
#   High Limit: 9742.25
#   Outliers: [13414, 38899, 20256, 28026, 13991]...
#
# Column: COPD_prevalence
#   Number of outliers: 30
#   Low Limit: 2.3500000000000005
#   High Limit: 15.549999999999999
#   Outliers: [18.1, 17.0, 15.8, 17.0, 16.4]...
#
# Column: COPD_Lower 95% CI
#   Number of outliers: 29
#   Low Limit: 1.9500000000000002
#   High Limit: 13.549999999999999
#   Outliers: [15.9, 14.6, 14.7, 14.2, 13.6]...
#
# Column: COPD_Upper 95% CI
#   Number of outliers: 33
#   Low Limit: 3.1000000000000005
#   High Limit: 17.5
#   Outliers: [20.3, 19.3, 18.0, 19.3, 18.6]...
#
# Column: COPD_number
#   Number of outliers: 369
#   Low Limit: -5053.0
#   High Limit: 10595.0
#   Outliers: [14692, 41253, 20400, 28849, 14595]...
#
# Column: diabetes_prevalence
#   Number of outliers: 33
#   Low Limit: 5.799999999999997
#   High Limit: 20.200000000000003
#   Outliers: [20.6, 20.5, 21.1, 25.6, 22.3]...
#
# Column: diabetes_Lower 95% CI
#   Number of outliers: 39
#   Low Limit: 5.200000000000003
#   High Limit: 18.799999999999997
#   Outliers: [19.4, 19.5, 19.9, 24.2, 19.0]...
#
# Column: diabetes_Upper 95% CI
#   Number of outliers: 29
#   Low Limit: 6.399999999999999
#   High Limit: 21.6
#   Outliers: [21.9, 22.2, 27.0, 23.6, 23.7]...
#
# Column: diabetes_number
#   Number of outliers: 388
#   Low Limit: -7049.5
#   High Limit: 14916.5
#   Outliers: [20520, 68819, 34952, 45540, 27581]...
#
# Column: CKD_prevalence
#   Number of outliers: 49
#   Low Limit: 2.0500000000000007
#   High Limit: 4.85
#   Outliers: [5.8, 5.0, 5.3, 5.0, 5.1]...
#
# Column: CKD_Lower 95% CI
#   Number of outliers: 68
#   Low Limit: 1.9999999999999998
#   High Limit: 4.4
#   Outliers: [4.5, 4.5, 5.4, 4.7, 4.9]...
#
# Column: CKD_Upper 95% CI
#   Number of outliers: 41
#   Low Limit: 2.1
#   High Limit: 5.299999999999999
#   Outliers: [6.2, 5.3, 5.6, 5.3, 5.4]...
#
# Column: CKD_number
#   Number of outliers: 386
#   Low Limit: -1877.5
#   High Limit: 3968.5
#   Outliers: [5479, 17072, 8511, 11166, 6253]...

# %%
def remove_outliers(df, outlier_info):
    
    for col, info in outlier_info.items():
        lower_limit = info['lower_bound']
        upper_limit = info['upper_bound']
        
        if lower_limit < 0:
            df = df[df[col] >= lower_limit]
        if upper_limit > 0:
            df = df[df[col] <= upper_limit]

        
    return df

# %%
df_without_outliers = remove_outliers(df.copy(), outlier_info=outlier_info)
df_without_outliers.describe().round(2)
# Out:
#            fips    TOT_POP       0-9  0-9 y/o % of total pop    19-Oct  \
# count   1036.00    1036.00   1036.00                 1036.00   1036.00
# mean   28614.27   25643.53   2994.02                   11.74   3250.41
# std    13892.33   19858.18   2336.16                    1.40   2545.34
# min     1001.00     465.00     55.00                    7.32     47.00
# 25%    18164.00   10870.00   1281.75                   10.81   1384.75
# 50%    27037.00   19995.50   2273.00                   11.77   2543.50
# 75%    39383.00   35872.25   4192.75                   12.60   4543.25
# max    55141.00  117360.00  15330.00                   16.40  16247.00
#
#        10-19 y/o % of total pop     20-29  20-29 y/o % of total pop     30-39  \
# count                   1036.00   1036.00                   1036.00   1036.00
# mean                      12.66   3001.87                     11.30   2949.89
# std                        1.19   2490.39                      1.43   2369.07
# min                        8.57     52.00                      7.89     37.00
# 25%                       11.92   1212.00                     10.31   1204.00
# 50%                       12.67   2275.50                     11.21   2253.50
# 75%                       13.38   4161.50                     12.04   4186.00
# max                       16.51  15146.00                     16.89  16085.00
#
#        30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# count                   1036.00  ...      1036.00              1036.00
# mean                      11.31  ...      1955.25                13.00
# std                        1.04  ...      1535.51                 1.88
# min                        7.77  ...        24.00                 7.90
# 25%                       10.62  ...       797.50                11.60
# 50%                       11.23  ...      1517.50                12.90
# 75%                       11.87  ...      2690.50                14.40
# max                       15.53  ...      9070.00                18.80
#
#        diabetes_Lower 95% CI  diabetes_Upper 95% CI  diabetes_number  \
# count                1036.00                1036.00          1036.00
# mean                   11.96                  14.04          2571.90
# std                     1.81                   1.95          1969.30
# min                     7.30                   8.60            37.00
# 25%                    10.60                  12.58          1133.25
# 50%                    11.90                  14.00          2045.50
# 75%                    13.32                  15.50          3522.50
# max                    17.40                  20.20         11540.00
#
#        CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI  CKD_number  \
# count         1036.00           1036.00           1036.00     1036.00
# mean             3.44              3.19              3.72      675.62
# std              0.36              0.33              0.39      508.77
# min              2.40              2.30              2.60       11.00
# 25%              3.20              3.00              3.40      304.00
# 50%              3.40              3.20              3.70      537.00
# 75%              3.70              3.40              4.00      922.00
# max              4.60              4.30              4.90     2805.00
#
#        Urban_rural_code
# count           1036.00
# mean               5.00
# std                1.28
# min                2.00
# 25%                4.00
# 50%                6.00
# 75%                6.00
# max                6.00
#
# [8 rows x 106 columns]

# %%
def train_split(target, df, test_size=0.2, random_state=42):
    return train_test_split(df.drop(columns=target), df[target], test_size=test_size, random_state=random_state)

# %%
def standard_scaler(X_train, X_test, filename: str):

    scaler = StandardScaler()
    scaler.fit(X_train)
    
    X_train_norm = scaler.transform(X_train)
    X_test_norm = scaler.transform(X_test)

    X_train_norm = pd.DataFrame(X_train_norm, index=X_train.index, columns=X_train.columns)
    X_test_norm = pd.DataFrame(X_test_norm, index=X_test.index, columns=X_test.columns)

    dump(scaler, f'../data/processed/std_transform_{filename}.sav')

    return X_train_norm, X_test_norm

def min_max_scaler(X_train, X_test, reference: str):
    
    scaler = MinMaxScaler()
    scaler.fit(X_train)
    
    X_train_minmax = scaler.transform(X_train)
    X_train_minmax = pd.DataFrame(X_train_minmax, index = X_train.index, columns=X_train.columns)

    X_test_minmax = scaler.transform(X_test)
    X_test_minmax = pd.DataFrame(X_test_minmax, index = X_test.index, columns=X_test.columns)
    
    dump(scaler, f'../data/processed/minmax_{reference}.sav')

    return X_train_minmax, X_test_minmax

# %%
TARGET = 'diabetes_prevalence'

X_train_with_outliers, X_test_with_outliers, y_train, y_test = train_split(TARGET, df, test_size=0.2, random_state=42)
X_train_without_outliers, X_test_without_outliers, y_train_without_outliers, y_test_without_outliers  = train_split(TARGET, df_without_outliers, test_size=0.2, random_state=42)

#Default
X_train_with_outliers.to_csv('../data/processed/X_train_with_outliers_ts_02_rs_42.csv', index=False)
X_test_with_outliers.to_csv('../data/processed/X_test_with_outliers_ts_02_rs_42.csv', index=False)

y_train.to_csv('../data/processed/y_train.csv', index=False)
y_test.to_csv('../data/processed/y_test.csv', index=False)

#Without outliers
X_train_without_outliers.to_csv('../data/processed/X_train_without_outliers_ts_02_rs_42.csv', index=False)
X_test_without_outliers.to_csv('../data/processed/X_test_without_outliers_ts_02_rs_42.csv', index=False)

y_train_without_outliers.to_csv('../data/processed/y_train_without_outliers.csv', index=False)
y_test_without_outliers.to_csv('../data/processed/y_test_without_outliers.csv', index=False)

# %%
X_train_with_outliers_std, X_test_with_outliers_std = standard_scaler(X_train_with_outliers, X_test_with_outliers, 'with_outliers')
X_train_without_outliers_std, X_test_without_outliers_std = standard_scaler(X_train_without_outliers, X_test_without_outliers, 'without_outliers')

X_train_with_outliers_minmax, X_test_with_outliers_minmax = min_max_scaler(X_train_with_outliers, X_test_with_outliers, 'with_outliers')
X_train_without_outliers_minmax, X_test_without_outliers_minmax = min_max_scaler(X_train_without_outliers, X_test_without_outliers, 'without_outliers')

# %%
def select_k_best(X_train, X_test, y_train, k, filename: str):

    selection_model = SelectKBest(f_regression, k=k)
    selection_model.fit(X_train, y_train)
    cols = selection_model.get_support()

    dump(selection_model, f'../data/processed/selection_model_{filename}.sav')

    return pd.DataFrame(selection_model.transform(X_train), columns=X_train.columns.values[cols]) , pd.DataFrame(selection_model.transform(X_test), columns=X_test.columns.values[cols])

# %%
K=15
X_train_with_outliers_selected, X_test_with_outliers_selected = select_k_best(X_train_with_outliers, X_test_with_outliers, y_train, K, 'with_outliers')
X_train_without_outliers_selected, X_test_without_outliers_selected = select_k_best(X_train_without_outliers, X_test_without_outliers, y_train_without_outliers, K, 'without_outliers')

# %%
# Correlation heatmap

import numpy as np
import seaborn as sns

plt.figure(figsize=(12, 10))

corr_matrix = X_train_with_outliers_selected.corr()

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

sns.heatmap(
    corr_matrix, 
    mask=mask,
    annot=True, 
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink": 0.75},
    annot_kws={"size": 10}
)

plt.title("Correlation Matrix", fontsize=16, fontweight="bold", pad=20)
plt.xticks(fontsize=12, rotation=45, ha="right")
plt.yticks(fontsize=12)

plt.show()

# %%
X_train_with_outliers_std_selected = X_train_with_outliers_std[X_train_with_outliers_selected.columns]
X_train_without_outliers_std_selected = X_train_without_outliers_std[X_train_without_outliers_selected.columns]

X_test_with_outliers_std_selected = X_test_with_outliers_std[X_test_with_outliers_selected.columns]
X_test_without_outliers_std_selected = X_test_without_outliers_std[X_test_without_outliers_selected.columns]


X_train_with_outliers_minmax_selected = X_train_with_outliers_minmax[X_train_with_outliers_selected.columns]
X_train_without_outliers_minmax_selected = X_train_without_outliers_minmax[X_train_without_outliers_selected.columns]

X_test_with_outliers_minmax_selected = X_test_with_outliers_minmax[X_test_with_outliers_selected.columns]
X_test_without_outliers_minmax_selected = X_test_without_outliers_minmax[X_test_without_outliers_selected.columns]

# %%
dfs_train = {
    'X_train_with_outliers_selected': X_train_with_outliers_selected,
    'X_train_with_outliers_std_selected': X_train_with_outliers_std_selected,
    'X_train_with_outliers_minmax_selected': X_train_with_outliers_minmax_selected,
}

dfs_train_without_outliers = {
    'X_train_without_outliers_selected': X_train_without_outliers_selected,
    'X_train_without_outliers_std_selected': X_train_without_outliers_std_selected,
    'X_train_without_outliers_minmax_selected': X_train_without_outliers_minmax_selected 
}

dfs_test = {
    'X_test_with_outliers_selected': X_test_with_outliers_selected,
    'X_test_with_outliers_std_selected': X_test_with_outliers_std_selected,
    'X_test_with_outliers_minmax_selected': X_test_with_outliers_minmax_selected,
}

dfs_test_without_outliers = {
    'X_test_without_outliers_selected': X_test_without_outliers_selected,
    'X_test_without_outliers_std_selected': X_test_without_outliers_std_selected,
    'X_test_without_outliers_minmax_selected': X_test_without_outliers_minmax_selected
}



for name, df in dfs_train.items():
    df.to_csv(f"../data/processed/{name}.csv", index=False)

for name, df in dfs_test.items(): 
    df.to_csv(f'../data/processed/{name}.csv', index=False)

for name, df in dfs_train_without_outliers.items():
    df.to_csv(f"../data/processed/{name}.csv", index=False)

for name, df in dfs_test_without_outliers.items(): 
    df.to_csv(f'../data/processed/{name}.csv', index=False)

# %%
train = list(dfs_train.values())
test = list(dfs_test.values())
train_without_outliers = list(dfs_train_without_outliers.values())
test_without_outliers = list(dfs_test_without_outliers.values())

results = []

# Default
for index, train_df in enumerate(train):
    model = LinearRegression()
    model.fit(train_df, y_train)
    y_pred = model.predict(test[index])

    results.append({
        'index': index,
        'df_train': list(dfs_train.keys())[index],
        'Intercept': model.intercept_,
        'Coefficients': model.coef_,
        'y_pred': y_pred
    })

# Without outliers
for index, train_df in enumerate(train_without_outliers):
    model = LinearRegression()
    model.fit(train_df, y_train_without_outliers)
    y_pred = model.predict(test_without_outliers[index])

    results.append({
        'index': index,
        'df_train': list(dfs_train_without_outliers.keys())[index],
        'Intercept': model.intercept_,
        'Coefficients': model.coef_,
        'y_pred': y_pred
    })


results = sorted(results, key=lambda x: x['Intercept'], reverse=True)
best_result = results[0]

print(f"Index: {best_result['index']}")
print(f"\ndf_train: {best_result['df_train']}")
print(f"\nIntercept: {best_result['Intercept']}")
print(f"\nCoefficients: {best_result['Coefficients']}")
# Out:
# Index: 1
#
# df_train: X_train_with_outliers_std_selected
#
# Intercept: 13.041640127388533
#
# Coefficients: [-0.00398128  0.00288812  0.74996791 -0.37751348 -0.36826725  0.36820115
#  -0.09668548 -0.27807018  0.11896858 -0.11753558  1.28182026  1.40929728
#   0.01180163 -0.01001318  0.00470785]

# %%
print(f"Mean squared error: {mean_squared_error(y_test, best_result['y_pred']):.2f}")
print(f"Coefficient of determination: {r2_score(y_test, best_result['y_pred']):.2f}")
# Out:
# Mean squared error: 0.00
# Coefficient of determination: 1.00

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'fit_intercept': [True, False],
    'copy_X': [True, False],
    'n_jobs': [None, 1, -1],
    'positive': [True, False]
}

grid_search = GridSearchCV(estimator=LinearRegression(), param_grid=param_grid, cv=5, scoring='r2')
grid_search.fit(X_train_with_outliers_std_selected, y_train)

print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best R² Score: {grid_search.best_score_}")
# Out:
# Best Parameters: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# Best R² Score: 0.9997543137195558

# %%
best_model = grid_search.best_estimator_
y_pred_test = best_model.predict(X_test_with_outliers_std_selected)
print(f"Test Mean Squared Error: {mean_squared_error(y_test, y_pred_test):.4f}")
print(f"Test Coefficient of Determination: {r2_score(y_test, y_pred_test):.4f}")
# Out:
# Test Mean Squared Error: 0.0019
# Test Coefficient of Determination: 0.9998

# %%
import joblib


alphas = [0.1, 0.5, 1.0, 2.0, 5.0, 10.0, 50.0, 100.0]

lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train_with_outliers_std_selected, y_train)
y_pred = lasso_model.predict(X_test_with_outliers_std_selected)

r2_scores = []
print("\nLasso Regression:")
for alpha in alphas:
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train_with_outliers_std_selected, y_train)
    y_pred = lasso_model.predict(X_test_with_outliers_std_selected)
    r2 = r2_score(y_test, y_pred)
    r2_scores.append(r2)
    print(f"Alpha: {alpha} | MSE: {mean_squared_error(y_test, y_pred):.4f} | R²: {r2:.4f}")

best_alpha = alphas[r2_scores.index(max(r2_scores))]
joblib.dump(Lasso(alpha=best_alpha).fit(X_train_with_outliers_std_selected, y_train), f'../models/best_lasso_alpha_{best_alpha}.pkl')
print(f"Best model saved with alpha={best_alpha} and R²={max(r2_scores):.4f}")

plt.figure(figsize=(8, 6))
plt.xscale('log')
plt.plot(alphas, r2_scores, marker='o')
plt.xlabel('Alpha')
plt.ylabel('R² Score')
plt.title('R² Score vs Alpha (Lasso) [Log Scale]')    
plt.show()
# Out:
# Lasso Regression:
# Alpha: 0.1 | MSE: 0.0142 | R²: 0.9982
# Alpha: 0.5 | MSE: 0.2848 | R²: 0.9646
# Alpha: 1.0 | MSE: 1.1236 | R²: 0.8603
# Alpha: 2.0 | MSE: 4.4691 | R²: 0.4444
# Alpha: 5.0 | MSE: 8.0685 | R²: -0.0032
# Alpha: 10.0 | MSE: 8.0685 | R²: -0.0032
# Alpha: 50.0 | MSE: 8.0685 | R²: -0.0032
# Alpha: 100.0 | MSE: 8.0685 | R²: -0.0032
# Best model saved with alpha=0.1 and R²=0.9982

# %% [markdown]
# High R² Scores for Low Alpha: At lower values of Alpha (closer to 10−110^{-1}), the R² score is close to 1, indicating a very good fit of the model.
#
# Decline in R² with Increasing Alpha: As Alpha increases, the R² score decreases significantly. This trend continues, with R² approaching 0 for Alphas greater than 10010^{0} (1).
